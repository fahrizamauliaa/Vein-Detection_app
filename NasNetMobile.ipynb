# %% [raw]
# CNN dengan Model NASNetMobile untuk Deteksi Vena di Dorsal Hand

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization, Flatten, Input, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from IPython.display import display, HTML
# Out:
# C:\Users\dragon\anaconda3\envs\CNN-1\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# WARNING:tensorflow:From C:\Users\dragon\anaconda3\envs\CNN-1\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [raw]
# Iterate through the folders to create a dataframe of the form filepaths labels

# %%
sdir = r'C:\Users\dragon\Documents\A Jupyter CNN\uji coba\dataset-1'

# %%
filepaths = []
labels = []
classlist = os.listdir(sdir)
print(f"Found classes: {classlist}")

for klass in classlist:
    classpath = os.path.join(sdir, klass)
    if os.path.isdir(classpath):
        flist = os.listdir(classpath)
        print(f"Class '{klass}' has {len(flist)} images")
        for f in flist:
            fpath = os.path.join(classpath, f)
            filepaths.append(fpath)
            labels.append(klass)                   

Fseries = pd.Series(filepaths, name='filepaths')
Lseries = pd.Series(labels, name='labels')    
df = pd.concat([Fseries, Lseries], axis=1)
print(df.head())
print(df['labels'].value_counts())
# Out:
# Found classes: ['NO', 'YES']
# Class 'NO' has 800 images
# Class 'YES' has 800 images
#                                            filepaths labels
# 0  C:\Users\dragon\Documents\A Jupyter CNN\uji co...     NO
# 1  C:\Users\dragon\Documents\A Jupyter CNN\uji co...     NO
# 2  C:\Users\dragon\Documents\A Jupyter CNN\uji co...     NO
# 3  C:\Users\dragon\Documents\A Jupyter CNN\uji co...     NO
# 4  C:\Users\dragon\Documents\A Jupyter CNN\uji co...     NO
# labels
# NO     800
# YES    800
# Name: count, dtype: int64

# %% [raw]
# Split df into train_df, test_df and valid_df

# %%
train_split = 0.7
test_split = 0.15
dummy_split = test_split / (1 - train_split)

train_df, dummy_df = train_test_split(
    df,
    train_size=train_split,
    shuffle=True,
    random_state=123,
    stratify=df['labels']
)

test_df, valid_df = train_test_split(
    dummy_df,
    train_size=dummy_split,
    shuffle=True,
    random_state=123,
    stratify=dummy_df['labels']
)

print(
    'train_df length:', len(train_df),
    '  test_df length:', len(test_df),
    '  valid_df length:', len(valid_df)
)
# Out:
# train_df length: 1120   test_df length: 239   valid_df length: 241

# %% [raw]
# Create train, test, valid generators

# %%
height = 224  # NASNetMobile optimal input size
width = 224
channels = 3  # Convert grayscale ke RGB untuk NASNetMobile
batch_size = 16  # Smaller batch size for NASNetMobile

img_shape = (height, width, channels)
img_size = (height, width)
length = len(test_df)
test_batch_size = sorted([int(length/n) for n in range(1, length+1) if length % n == 0 and length/n <= 80], reverse=True)[0]  
test_steps = int(length / test_batch_size)
print('test batch size:', test_batch_size, '  test steps:', test_steps)
# Out:
# test batch size: 1   test steps: 239

# %% [raw]
# Data augmentation untuk training set (lebih konservatif untuk medical imaging)

# %%
train_gen_data = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,  # Reduced rotation
    width_shift_range=0.05,  # Reduced shift
    height_shift_range=0.05,
    horizontal_flip=True,
    zoom_range=0.05,  # Reduced zoom
    brightness_range=[0.9, 1.1],  # Reduced brightness variation
    fill_mode='nearest'
)

train_gen = train_gen_data.flow_from_dataframe(
    train_df, 
    x_col='filepaths', 
    y_col='labels', 
    target_size=img_size, 
    class_mode='categorical',
    color_mode='rgb',  # Convert grayscale to RGB for NASNetMobile
    shuffle=True, 
    batch_size=batch_size
)
# Out:
# Found 1120 validated image filenames belonging to 2 classes.

# %% [raw]
# Validation generator (no augmentation)

# %%
valid_gen_data = ImageDataGenerator(rescale=1./255)
valid_gen = valid_gen_data.flow_from_dataframe(
    valid_df, 
    x_col='filepaths', 
    y_col='labels', 
    target_size=img_size, 
    class_mode='categorical',
    color_mode='rgb', 
    shuffle=True, 
    batch_size=batch_size
)
# Out:
# Found 241 validated image filenames belonging to 2 classes.

# %% [raw]
# Test generator (no augmentation)

# %%
test_gen_data = ImageDataGenerator(rescale=1./255)
test_gen = test_gen_data.flow_from_dataframe(
    test_df, 
    x_col='filepaths', 
    y_col='labels', 
    target_size=img_size, 
    class_mode='categorical',
    color_mode='rgb', 
    shuffle=False, 
    batch_size=test_batch_size
)

classes = list(train_gen.class_indices.keys())
print("Classes:", classes)
class_count = len(classes)
# Out:
# Found 239 validated image filenames belonging to 2 classes.
# Classes: ['NO', 'YES']

# %% [raw]
# Create function to show some image examples

# %%
def show_image_samples(gen):
    test_dict = gen.class_indices
    classes = list(test_dict.keys())    
    images, labels = next(gen)  # get a sample batch from the generator 
    plt.figure(figsize=(20, 20))
    length = len(labels)
    if length < 25:   # show maximum of 25 images
        r = length
    else:
        r = 25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image = images[i]
        plt.imshow(image)
        index = np.argmax(labels[i])
        class_name = classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

show_image_samples(train_gen)

# %% [raw]
# Create the model with NASNetMobile base

# %%
print("Loading NASNetMobile base model...")
base_model = tf.keras.applications.NASNetMobile(
    include_top=False, 
    weights="imagenet",
    input_tensor=Input(shape=(224, 224, 3)),
    pooling=None
) 
base_model.summary()
# Out:
# Loading NASNetMobile base model...
# WARNING:tensorflow:From C:\Users\dragon\anaconda3\envs\CNN-1\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\dragon\anaconda3\envs\CNN-1\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model: "NASNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  stem_conv1 (Conv2D)         (None, 111, 111, 32)         864       ['input_1[0][0]']
#
#  stem_bn1 (BatchNormalizati  (None, 111, 111, 32)         128       ['stem_conv1[0][0]']
#  on)
#
# ...

# %% [raw]
# Freeze the base model initially

# %%
base_model.trainable = False

model_name = 'NASNetMobile_VeinDetection'
print("Building model with NASNetMobile")
# Out:
# Building model with NASNetMobile

# %% [raw]
# Create the model with optimized architecture for medical imaging

# %%
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(len(classes), activation='softmax')
])

# %% [raw]
# Compile with lower learning rate for stability

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),  # Lower learning rate
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  NASNet (Functional)         (None, 7, 7, 1056)        4269716
#
#  global_average_pooling2d (  (None, 1056)              0
#  GlobalAveragePooling2D)
#
#  batch_normalization (Batch  (None, 1056)              4224
#  Normalization)
#
#  dense (Dense)               (None, 512)               541184
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  batch_normalization_2 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
# ...

# %% [raw]
# Define callbacks for gradual improvement

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss', 
        patience=8, 
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss', 
        factor=0.3, 
        patience=4, 
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='best_nasnet_vein_model.keras', 
        monitor='val_accuracy', 
        save_best_only=True, 
        verbose=1
    )
]

# %% [raw]
# First phase: Train with frozen base model

# %%
print("\n=== PHASE 1: Training with frozen NASNetMobile ===")
epochs_phase1 = 15

history_phase1 = model.fit(
    x=train_gen, 
    epochs=epochs_phase1, 
    validation_data=valid_gen,
    callbacks=callbacks,
    verbose=1
)
# Out:
# === PHASE 1: Training with frozen NASNetMobile ===
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\dragon\anaconda3\envs\CNN-1\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\dragon\anaconda3\envs\CNN-1\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 70/70 [==============================] - ETA: 0s - loss: 0.5972 - accuracy: 0.6911
# Epoch 1: val_accuracy improved from -inf to 0.86722, saving model to best_nasnet_vein_model.keras
# 70/70 [==============================] - 328s 3s/step - loss: 0.5972 - accuracy: 0.6911 - val_loss: 0.4283 - val_accuracy: 0.8672 - lr: 1.0000e-04
# Epoch 2/15
# 70/70 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.8170
# ...

# %% [raw]
# Second phase: Fine-tuning with unfrozen top layers

# %%
print("\n=== PHASE 2: Fine-tuning with unfrozen layers ===")
# Out:
# === PHASE 2: Fine-tuning with unfrozen layers ===

# %% [raw]
# Unfreeze the top layers of the base model

# %%
base_model.trainable = True

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input

base_model = tf.keras.applications.NASNetMobile(
    include_top=False, 
    weights="imagenet",
    input_tensor=Input(shape=(224, 224, 3)),
    pooling=None
)
print("Model dasar dimuat:", base_model.name)
base_model.trainable = True
print("Model dasar diatur ke trainable")
# Out:
# Model dasar dimuat: NASNet
# Model dasar diatur ke trainable

# %% [raw]
# Fine-tune from this layer onwards

# %%
fine_tune_at = len(base_model.layers) - 30

# %% [raw]
# Freeze all the layers before the `fine_tune_at` layer

# %%
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# %% [raw]
# Recompile with lower learning rate for fine-tuning

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),  # Much lower learning rate
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [raw]
# Continue training for fine-tuning

# %%
epochs_phase2 = 10
initial_epochs = epochs_phase1

callbacks_finetune = [
    EarlyStopping(
        monitor='val_loss', 
        patience=6, 
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss', 
        factor=0.5, 
        patience=3, 
        min_lr=1e-8,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='best_nasnet_vein_finetuned.keras', 
        monitor='val_accuracy', 
        save_best_only=True, 
        verbose=1
    )
]

history_phase2 = model.fit(
    x=train_gen,
    epochs=initial_epochs + epochs_phase2,
    initial_epoch=initial_epochs,
    validation_data=valid_gen,
    callbacks=callbacks_finetune,
    verbose=1
)
# Out:
# Epoch 16/25
# 70/70 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.8241
# Epoch 16: val_accuracy improved from -inf to 0.97510, saving model to best_nasnet_vein_finetuned.keras
# 70/70 [==============================] - 1005s 8s/step - loss: 0.4096 - accuracy: 0.8241 - val_loss: 0.0687 - val_accuracy: 0.9751 - lr: 1.0000e-05
# Epoch 17/25
# 70/70 [==============================] - ETA: 0s - loss: 0.3267 - accuracy: 0.8795
# Epoch 17: val_accuracy did not improve from 0.97510
# 70/70 [==============================] - 369s 5s/step - loss: 0.3267 - accuracy: 0.8795 - val_loss: 0.0842 - val_accuracy: 0.9668 - lr: 1.0000e-05
# Epoch 18/25
# 70/70 [==============================] - ETA: 0s - loss: 0.2358 - accuracy: 0.9098
# Epoch 18: val_accuracy did not improve from 0.97510
# 70/70 [==============================] - 350s 5s/step - loss: 0.2358 - accuracy: 0.9098 - val_loss: 0.0909 - val_accuracy: 0.9585 - lr: 1.0000e-05
# Epoch 19/25
# ...

# %% [raw]
# Define function to print text in RGB foreground and background colors

# %%
def print_in_color(txt_msg, fore_tupple, back_tupple):
    rf, gf, bf = fore_tupple
    rb, gb, bb = back_tupple
    msg = '{0}' + txt_msg
    mat = '\33[38;2;' + str(rf) + ';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' + str(gb) + ';' + str(bb) + 'm' 
    print(msg.format(mat), flush=True)
    print('\33[0m', flush=True)
    return

# %% [raw]
# Define function to plot the training data (combined phases)

# %%
def tr_plot_combined(tr_data1, tr_data2, start_epoch):
    # Combine history from both phases
    tacc = tr_data1.history['accuracy'] + tr_data2.history['accuracy']
    tloss = tr_data1.history['loss'] + tr_data2.history['loss']
    vacc = tr_data1.history['val_accuracy'] + tr_data2.history['val_accuracy']
    vloss = tr_data1.history['val_loss'] + tr_data2.history['val_loss']
    
    Epoch_count = len(tacc) + start_epoch
    Epochs = []
    for i in range(start_epoch, Epoch_count):
        Epochs.append(i + 1)   
    
    index_loss = np.argmin(vloss)
    val_lowest = vloss[index_loss]
    index_acc = np.argmax(vacc)
    acc_highest = vacc[index_acc]
    
    plt.style.use('fivethirtyeight')
    sc_label = 'best epoch= ' + str(index_loss + 1 + start_epoch)
    vc_label = 'best epoch= ' + str(index_acc + 1 + start_epoch)
    
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))
    # Loss plot
    axes[0].plot(Epochs, tloss, 'r', label='Training loss')
    axes[0].plot(Epochs, vloss, 'g', label='Validation loss')
    axes[0].axvline(x=epochs_phase1, color='blue', linestyle='--', alpha=0.7, label='Fine-tuning start')
    axes[0].scatter(index_loss + 1 + start_epoch, val_lowest, s=150, c='blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss (NASNetMobile)')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    
    # Accuracy plot
    axes[1].plot(Epochs, tacc, 'r', label='Training Accuracy')
    axes[1].plot(Epochs, vacc, 'g', label='Validation Accuracy')
    axes[1].axvline(x=epochs_phase1, color='blue', linestyle='--', alpha=0.7, label='Fine-tuning start')
    axes[1].scatter(index_acc + 1 + start_epoch, acc_highest, s=150, c='blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy (NASNetMobile)')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    
    plt.tight_layout()
    plt.show()

# %% [raw]
# Define function to generate the confusion matrix and classification report

# %%
def print_info(test_gen, preds, print_code, save_dir, subject):
    class_dict = test_gen.class_indices
    labels = test_gen.labels
    file_names = test_gen.filenames 
    error_list = []
    true_class = []
    pred_class = []
    prob_list = []
    new_dict = {}
    error_indices = []
    y_pred = []
    
    for key, value in class_dict.items():
        new_dict[value] = key
    
    classes = list(new_dict.values())
    dict_as_text = str(new_dict)
    dict_name = subject + '-' + str(len(classes)) + '.txt'  
    dict_path = os.path.join(save_dir, dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    
    errors = 0      
    for i, p in enumerate(preds):
        pred_index = np.argmax(p)        
        true_index = labels[i]
        if pred_index != true_index:
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors = errors + 1
        y_pred.append(pred_index)    
    
    if print_code != 0:
        if errors > 0:
            if print_code > errors:
                r = errors
            else:
                r = print_code           
            msg = '{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class', 'True Class', 'Probability')
            print_in_color(msg, (0, 255, 0), (55, 65, 80))
            for i in range(r):                
                split1 = os.path.split(error_list[i])                
                split2 = os.path.split(split1[0])                
                fname = split2[1] + '/' + split1[1]
                msg = '{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i], true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255, 255, 255), (55, 65, 60))
        else:
            msg = 'With accuracy of 100% there are no errors to print'
            print_in_color(msg, (0, 255, 0), (55, 65, 80))
    
    if errors > 0:
        plot_bar = []
        plot_class = []
        for key, value in new_dict.items():        
            count = error_indices.count(key) 
            if count != 0:
                plot_bar.append(count)
                plot_class.append(value)
        fig = plt.figure()
        fig.set_figheight(len(plot_class) / 3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c = plot_class[i]
            x = plot_bar[i]
            plt.barh(c, x)
            plt.title('Errors by Class on Test Set - NASNetMobile')
    
    y_true = np.array(labels)        
    y_pred = np.array(y_pred)
    
    if len(classes) <= 30:
        cm = confusion_matrix(y_true, y_pred)        
        length = len(classes)
        if length < 8:
            fig_width = 8
            fig_height = 8
        else:
            fig_width = int(length * 0.5)
            fig_height = int(length * 0.5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length) + 0.5, classes, rotation=90)
        plt.yticks(np.arange(length) + 0.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix - Vein Detection (NASNetMobile)")
        plt.show()
    
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %% [raw]
# Evaluate model on the test set then save the model

# %%
tr_plot_combined(history_phase1, history_phase2, 0)
save_dir = r'./'
subject = 'vein_detection_nasnet'

# %% [raw]
# Load best model if saved

# %%
if os.path.exists('best_nasnet_vein_finetuned.keras'):
    model = load_model('best_nasnet_vein_finetuned.keras')
    print("Loaded best fine-tuned model from training")
elif os.path.exists('best_nasnet_vein_model.keras'):
    model = load_model('best_nasnet_vein_model.keras')
    print("Loaded best model from phase 1 training")

acc = model.evaluate(test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=False)[1] * 100
msg = f'Accuracy on the test set is {acc:5.2f}%'
print_in_color(msg, (0, 255, 0), (55, 65, 80))

save_id = str(model_name + '-' + subject + '-' + str(acc)[:str(acc).rfind('.') + 3] + '.keras')
save_loc = os.path.join(save_dir, save_id)
model.save(save_loc)
print(f"Model saved as: {save_id}")
# Out:
# Loaded best fine-tuned model from training
# 239/239 [==============================] - 111s 119ms/step - loss: 0.0316 - accuracy: 0.9916
# Accuracy on the test set is 99.16%
#
# Model saved as: NASNetMobile_VeinDetection-vein_detection_nasnet-99.16.keras

# %% [raw]
# Make predictions on test set and generate confusion matrix and classification report

# %%
print_code = 0
preds = model.predict(test_gen) 
print_info(test_gen, preds, print_code, save_dir, subject)

print("\n" + "="*60)
print("TRAINING COMPLETED - NASNetMobile Model for Vein Detection")
print("="*60)
print(f"Final Test Accuracy: {acc:.2f}%")
print("Model files created:")
print("- best_nasnet_vein_model.keras (Phase 1)")
print("- best_nasnet_vein_finetuned.keras (Phase 2)")
print(f"- {save_id} (Final model)")
print("="*60)
# Out:
# 239/239 [==============================] - 60s 98ms/step
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#           NO       1.00      0.98      0.99       119
#          YES       0.98      1.00      0.99       120
#
#     accuracy                           0.99       239
#    macro avg       0.99      0.99      0.99       239
# weighted avg       0.99      0.99      0.99       239
#
#
# ...
# TRAINING COMPLETED - NASNetMobile Model for Vein Detection
# ...
# Final Test Accuracy: 99.16%
# Model files created:
# - best_nasnet_vein_model.keras (Phase 1)
# - best_nasnet_vein_finetuned.keras (Phase 2)
# - NASNetMobile_VeinDetection-vein_detection_nasnet-99.16.keras (Final model)
# ...
